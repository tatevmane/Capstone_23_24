# %%
import pandas as pd

# %%
df = pd.read_csv("179_cases - Sheet1.csv")
df.head()
# Out:
#    Case ID                                          Case Name  \
# 0        1  A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist....
# 1        2  A.D. v. Best Western Int_l, Inc., 2023 U.S. Di...
# 2        3  A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. D...
# 3        4  A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. D...
# 4        5  A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. D...
#
#    Sex Trafficking STATE AGENCY CRIME  CRIME_MINOR  CRIME_ADULT NAME  TRAINING
# 0                1   NaN    NaN   NaN          NaN          NaN  NaN       1.0
# 1                1   NaN    NaN   NaN          NaN          NaN  NaN       NaN
# 2                1   NaN    NaN   NaN          NaN          NaN  NaN       1.0
# 3                1   NaN    NaN   NaN          NaN          NaN  NaN       NaN
# 4                1   NaN    NaN   NaN          NaN          NaN  NaN       NaN
