# %% [markdown]
# **Relevent Source Materials**
#
# https://medium.com/@bedigunjit/simple-guide-to-text-classification-nlp-using-svm-and-naive-bayes-with-python-421db3a72d34
#
# ETA Module 6, Vectorization with SciKit Learn
#
# Stat. Learning Final Project

# %% [markdown]
# ### Import

# %%
import os
from glob import glob
import pandas as pd
import numpy as np
import re
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, svm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### SetUp

# %%
## MODIFY THIS
# get path to your folder that holds the txt files
source_files = "C:/Users/jacqu/Downloads/Court Case PDFs/Court Case TXTs"
# outputs a list of all the txt files in the folder
source_file_list = sorted(glob(f"{source_files}/*.txt"))

# creates a list of tuples with an elememt for the source path and
# for the file title
file_data = []
for source_file_path in source_file_list:
    # split might be different, recommend checking with INFO.sample() or .head()
    file_title = source_file_path.split('\\')[-1].split(".txt")[0]
    file_data.append((source_file_path, file_title))

# creating df with the file title as the index and source path as a col
INFO = pd.DataFrame(file_data, columns=['txt_path','file_title'])\
    .set_index('file_title').sort_index()
INFO.head()
# Out:
#                                                                                              txt_path
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  C:/Users/jacqu/Downloads/Court Case PDFs/Court...
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  C:/Users/jacqu/Downloads/Court Case PDFs/Court...
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/Court Case PDFs/Court...
# B.M. v. Wyndham Hotels                              C:/Users/jacqu/Downloads/Court Case PDFs/Court...
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309       C:/Users/jacqu/Downloads/Court Case PDFs/Court...

# %%
# making the CORPUS
## CORPUS df: multindex = doc name/index, sent. num, token num
## columns = pos tag, token str, term str (token str normalized)

narratives_list = []
for doc_idx, txt_path in enumerate(INFO['txt_path']):
    with open(txt_path, 'r',  encoding='utf-8') as file:
        narrative = file.read()
    narratives_list.append({"title": INFO.index[doc_idx], "narrative": narrative})

# Convert the list of dictionaries to a DataFrame
narratives = pd.DataFrame(narratives_list)
narratives = narratives.reset_index().set_index("title")
narratives = narratives.drop(columns=['index'])
narratives.head()
# Out:
#                                                                                             narrative
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  OPINION AND ORDER GRANTING DEFENDANT  SUMMIT H...
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  OPINION AND ORDER This matter comes before the...
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  OPINION AND ORDER This matter comes before the...
# B.M. v. Wyndham Hotels                              ORDER GRANTING IN PART AND DENYING IN  PART DE...
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309       [*1] ORDER AND JUDGMENT* _____________________...

# %%
df = pd.DataFrame(index=narratives.index)
df['sent_str'] = [nltk.sent_tokenize(narratives.narrative[x]) for x in range(len(narratives))]
df = df.explode('sent_str')
s1 = df.index.to_series()
s2 = s1.groupby(s1).cumcount()
df.index = [df.index, s2]
df.index.names = ['title','sent_num']
# nltk.word_tokenize(df.sent_str[x])
df['token_pos'] = [nltk.pos_tag(nltk.WhitespaceTokenizer().tokenize(df.sent_str[x])) for x in range(len(df))]
df = df.explode('token_pos')
s1 = df.index.to_series()
s2 = s1.groupby(s1).cumcount()
df.index = [df.index.get_level_values(level=0), df.index.get_level_values(level=1), s2]
df.index.names = ['title','sent_num', 'token_num']
df.drop(columns=['sent_str'], inplace=True)
df.head()
# Out:
#                                                                               token_pos
# title                                              sent_num token_num
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ... 0        0             (OPINION, NN)
#                                                             1                 (AND, CC)
#                                                             2              (ORDER, NNP)
#                                                             3           (GRANTING, NNP)
#                                                             4          (DEFENDANT, NNP)

# %%
df['token_str'] = df.token_pos.apply(lambda x: x[0].strip())
df['term_str'] = df.token_pos.apply(lambda x: x[0].lower().strip())
df['pos_tag'] = df.token_pos.apply(lambda x: x[1])
CORPUS = df.drop(columns="token_pos")
CORPUS.head()
# Out:
#                                                                        token_str  \
# title                                              sent_num token_num
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ... 0        0            OPINION
#                                                             1                AND
#                                                             2              ORDER
#                                                             3           GRANTING
#                                                             4          DEFENDANT
#
#                                                                         term_str  \
# title                                              sent_num token_num
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ... 0        0            opinion
#                                                             1                and
#                                                             2              order
#                                                             3           granting
#                                                             4          defendant
#
#                                                                       pos_tag
# title                                              sent_num token_num
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ... 0        0              NN
#                                                             1              CC
#                                                             2             NNP
#                                                             3             NNP
#                                                             4             NNP

# %%
np.random.seed(3418)

# %% [markdown]
# **Here's a question:** Do we want to get rid of stop words? Maybe use a custom list of stop words... and do we want to do lemmatization on the words? Consult Brain??? 0.0
#
# If the answer is no to one or both questions, we can just have a df with index: title and columns: raw_narrative, n_tokens and go straight to TFIDFVec. We don't need to do most of the steps above; just go straight from narratives df to tfidf_engine.fit_transform(narratives.narrative).

# %% [markdown]
# ### Vectorization with SciKit Learn, TFIDF

# %%
## DOC df: index = doc name/index
## columns = narrative str, num tokens

# %%
def gather_docs(CORPUS, ohco_level, term_col='term_str'):
    OHCO = CORPUS.index.names
    CORPUS[term_col] = CORPUS[term_col].astype('str')
    DOC = CORPUS.groupby(OHCO[:ohco_level])[term_col].apply(lambda x:' '.join(x)).to_frame('doc_str')
    return DOC

# %%
DOC = gather_docs(CORPUS, 1)
DOC['n_tokens'] = DOC.doc_str.apply(lambda x: len(x.split()))
DOC.head()
# Out:
#                                                                                               doc_str  \
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  opinion and order granting defendant summit ho...
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  opinion and order this matter comes before the...
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  opinion and order this matter comes before the...
# B.M. v. Wyndham Hotels                              order granting in part and denying in part def...
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309       [*1] order and judgment* _____________________...
#
#                                                     n_tokens
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...      3608
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...      2940
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...      2926
# B.M. v. Wyndham Hotels                                  7354
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309           1933

# %%
ngram_range = (2,2)
n_terms = 1000

# %% [markdown]
# **Applying TFIDF Vectorization**

# %%
tfidf_engine = TfidfVectorizer(
    stop_words = 'english',
    ngram_range = ngram_range,
    max_features = n_terms,
    norm = 'l2', 
    use_idf = True)

# %% [markdown]
# **Vectorized data**

# %%
X = tfidf_engine.fit_transform(DOC.doc_str)
print(X[:1])
# Out:
#   (0, 607)	0.017124985771566223
#   (0, 367)	0.017124985771566223
#   (0, 141)	0.015460942182795936
#   (0, 761)	0.013840263039999507
#   (0, 516)	0.017124985771566223
#   (0, 470)	0.012887562575125163
#   (0, 49)	0.015460942182795936
#   (0, 819)	0.015958974638220037
#   (0, 115)	0.03781512146259613
#   (0, 933)	0.0463828265483878
#   (0, 527)	0.012082065809330791
#   (0, 860)	0.011606703175799815
#   (0, 137)	0.015460942182795936
#   (0, 533)	0.015958974638220037
#   (0, 736)	0.013186237336323806
#   (0, 746)	0.030921884365591873
#   (0, 934)	0.06849994308626489
#   (0, 487)	0.0463828265483878
#   (0, 237)	0.010966058748964207
#   (0, 181)	0.04376406044771847
#   (0, 695)	0.017124985771566223
#   (0, 120)	0.02637247467264761
#   (0, 252)	0.025775125150250325
#   (0, 44)	0.01350302437129094
#   (0, 42)	0.016509523975400443
#   :	:
#   (0, 759)	0.013840263039999507
#   (0, 461)	0.05483029374482104
#   (0, 662)	0.017822738807826602
#   (0, 302)	0.015460942182795936
#   (0, 247)	0.06383589855288015
#   (0, 362)	0.040509073113872814
#   (0, 415)	0.019580936038495318
#   (0, 546)	0.05835208059695795
#   (0, 413)	0.055884706720862924
#   (0, 890)	0.0323065529307139
#   (0, 465)	0.03701103971383426
#   (0, 737)	0.10822659527957154
#   (0, 385)	0.07911742401794283
#   (0, 484)	0.012082065809330791
#   (0, 863)	0.03191794927644007
#   (0, 810)	0.014200777407551319
#   (0, 789)	0.014200777407551319
#   (0, 973)	0.012887562575125163
#   (0, 939)	0.01117100210459857
#   (0, 732)	0.2062010012020026
#   (0, 556)	0.5117470800144525
#   (0, 821)	0.5117470800144525
#   (0, 745)	0.03866268772537549
#   (0, 393)	0.01117100210459857
#   (0, 660)	0.05738565561629114

# %% [markdown]
# **Learned vocabulary**

# %%
import itertools
print(dict(itertools.islice(tfidf_engine.vocabulary_.items(), 5)))
# Out:
# {'motion dismiss': 660, 'district judge': 393, 'plaintiff filed': 745, 'residence inn': 821, 'inn portland': 556}

# %%
TFIDF = pd.DataFrame(X.toarray(), columns=tfidf_engine.get_feature_names_out(), index=DOC.index)
TFIDF.head()
# Out:
#                                                     07 2023  07057 07057  \
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  0.00000          0.0
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  0.00000          0.0
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  0.00000          0.0
# B.M. v. Wyndham Hotels                              0.00000          0.0
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309       0.31267          0.0
#
#                                                     07057 page     10 11  \
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...         0.0  0.000000
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...         0.0  0.000000
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...         0.0  0.000000
# B.M. v. Wyndham Hotels                                     0.0  0.030476
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309              0.0  0.000000
#
#                                                     10th cir  11 12  11th cir  \
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  0.000000    0.0  0.011384
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  0.000000    0.0  0.023652
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  0.000000    0.0  0.027196
# B.M. v. Wyndham Hotels                              0.000000    0.0  0.000000
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309       0.368692    0.0  0.000000
#
#                                                      11th ed     12 07  12 13  \
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  0.000000  0.000000    0.0
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  0.016578  0.000000    0.0
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  0.019062  0.000000    0.0
# B.M. v. Wyndham Hotels                              0.000000  0.000000    0.0
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309       0.000000  0.295097    0.0
#
#                                                     ...  wyndham hotels  \
# title                                               ...
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  ...        0.015461
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  ...        0.016061
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  ...        0.018468
# B.M. v. Wyndham Hotels                              ...        0.062301
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309       ...        0.000000
#
#                                                     xxx 5542  xxx xxx  \
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...       0.0      0.0
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...       0.0      0.0
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...       0.0      0.0
# B.M. v. Wyndham Hotels                                   0.0      0.0
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309            0.0      0.0
#
#                                                     year old  years life  \
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...       0.0         0.0
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...       0.0         0.0
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...       0.0         0.0
# B.M. v. Wyndham Hotels                                   0.0         0.0
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309            0.0         0.0
#
#                                                     years old  \
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...   0.011171
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...   0.000000
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...   0.000000
# B.M. v. Wyndham Hotels                               0.009003
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309        0.000000
#
#                                                     york jurisdiction  \
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...                0.0
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...                0.0
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...                0.0
# B.M. v. Wyndham Hotels                                            0.0
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309                     0.0
#
#                                                     york state  zero point  \
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...         0.0         0.0
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...         0.0         0.0
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...         0.0         0.0
# B.M. v. Wyndham Hotels                                     0.0         0.0
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309              0.0         0.0
#
#                                                     zte phone
# title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...        0.0
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...        0.0
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...        0.0
# B.M. v. Wyndham Hotels                                    0.0
# Bacon v. Marshall, 2023 U.S. App. LEXIS 32309             0.0
#
# [5 rows x 1000 columns]

# %%
TFIDF.stack().to_frame('score').score.nlargest(20).to_frame('score')
# Out:
#                                                                            score
# title
# United States v. Wilkins, 538 F. Supp. 3d 49       mr wilkins           0.923909
# State v. Chatman, 2023 La. App. LEXIS 2102         ms jones             0.896280
# United States v. Woods, 2021 U.S. Dist. LEXIS 8... cornelius galloway   0.868035
# McSean v. LeMons, 2023 U.S. Dist. LEXIS 217918     8th cir              0.839268
# Kocher v. Sec_y VA., 2023 U.S. App. LEXIS 32355    federal sector       0.819387
# Rice Enters., LLC v. RSUI Indem. Co., 2023 U.S.... umbrella policy      0.768822
# D.B. v. IE Hotel Grp., LLC, 2023 U.S. Dist. LEX... g6 defendants        0.747694
# United States v. Robinson                          jane doe             0.743498
# United States v. Smith, 2023 U.S. Dist. LEXIS 2... minor victim         0.726214
# State v. Taylor-Hollingsworth, 2023 Ohio App. L... aggravated robbery   0.696958
# Lewis v. Senior Lifestyle, 2023 U.S. Dist. LEXI... senior lifestyle     0.678958
# State v. Davis, 2023-Ohio-4389                     postrelease control  0.675003
# State v. Jose Y., 2023 N.J. Super. Unpub. LEXIS... 3472 21              0.663796
# United States v. Crow, 2023 U.S. App. LEXIS 32380  22 14267             0.652208
# State v. Martinez-Mejia, 2023 N.J. Super. LEXIS... agent cruz           0.650411
# Greene v. State, 2023 Ind. App. Unpub. LEXIS 1393  level felony         0.640281
# State v. Nelson, 2023 Iowa App. LEXIS 941          parking lot          0.625031
# Subh v. Sec. Guard, Inc., 2023 U.S. Dist. LEXIS... mr revell            0.623149
# Rivas v. State, 2023 Fla. App. LEXIS 8246          years old            0.621399
# People v. De Jesus Hernandez, 2023 Cal. App. Un... trial court          0.620507

# %% [markdown]
# ### VOCAB DF
# Making a vocabulary list with significant uni/bi grams based on tfidf...

# %%
VOCAB = TFIDF.mean().to_frame('tfidf_mean')
VOCAB.sort_values('tfidf_mean', ascending=False).head(20)
# Out:
#                    tfidf_mean
# sex trafficking      0.073895
# united states        0.067361
# trial court          0.061735
# district court       0.060788
# dist lexis           0.038739
# criminal history     0.028859
# 8th cir              0.028184
# 4th cir              0.026022
# commercial sex       0.024677
# supp 3d              0.024112
# 3d cir               0.023842
# years old            0.023637
# defendant did        0.022933
# amendment 821        0.021519
# ed 2d                0.021517
# plaintiff alleges    0.019587
# cal app              0.018926
# did receive          0.018861
# motion dismiss       0.018846
# title vii            0.017948

# %% [raw]
# VOCAB['df'] = TFIDF[TFIDF > 0].count()
# VOCAB['dfidf'] = VOCAB.df * np.log2(len(TFIDF)/VOCAB.df)
# VOCAB.sort_values('dfidf', ascending=False).head(10)

# %% [markdown]
# ### Logistic Regression

# %% [raw]
# # Classifier - Algorithm - Logistic Reg.
# # fit the training dataset on the classifier, L2 penalty
# LR = LogisticRegression(solver = 'liblinear', C=10, penalty = 'l2')
# LR.fit(X,Y)
# # predict the labels on validation dataset
# predictions_LR = LR.predict(test_X)
# # Use accuracy_score function to get the accuracy
# print("LR Accuracy Score -> ", accuracy_score(predictions_LR, test_Y)*100)

# %% [markdown]
# ### SVM

# %% [raw]
# # Classifier - Algorithm - SVM
# # fit the training dataset on the classifier
# SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
# SVM.fit(X,Y)
# # predict the labels on validation dataset
# predictions_SVM = SVM.predict(test_X)
# # Use accuracy_score function to get the accuracy
# print("SVM Accuracy Score -> ", accuracy_score(predictions_SVM, test_Y)*100)
