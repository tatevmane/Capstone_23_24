# %%
default_path = "C:/Users/jacqu/Downloads/"
source_path = default_path+"trials/78_cases_pdf"
destination_path = default_path+"trials/78_cases_txt"

# %%
import sys
sys.path.append("C:/Users/jacqu/OneDrive/Documents/MSDS-at-UVA-2023/Projects/Capstone/Spring 24") 
from extraction_run import Extraction

# %%
mydf = Extraction(source_path, destination_path)

# %% [raw]
# mydf.process_pdfs()

# %%
INFO = mydf.create_info()
INFO.head()
# Out:
#                                                                                         pdf_path  \
# file_title
# Baston v. United States, 2019 U.S. Dist. LEXIS ...  C:/Users/jacqu/Downloads/trials/78_cases_pdf
# Baston v. United States, 2019 U.S. Dist. LEXIS ...  C:/Users/jacqu/Downloads/trials/78_cases_pdf
# Baston v. United States, 2020 U.S. Dist. LEXIS ...  C:/Users/jacqu/Downloads/trials/78_cases_pdf
# Bell v. United States, 2017 U.S. Dist. LEXIS 22...  C:/Users/jacqu/Downloads/trials/78_cases_pdf
# Ditullio v. Boehm, 2010 U.S. Dist. LEXIS 148772     C:/Users/jacqu/Downloads/trials/78_cases_pdf
#
#                                                                                         txt_path
# file_title
# Baston v. United States, 2019 U.S. Dist. LEXIS ...  C:/Users/jacqu/Downloads/trials/78_cases_txt
# Baston v. United States, 2019 U.S. Dist. LEXIS ...  C:/Users/jacqu/Downloads/trials/78_cases_txt
# Baston v. United States, 2020 U.S. Dist. LEXIS ...  C:/Users/jacqu/Downloads/trials/78_cases_txt
# Bell v. United States, 2017 U.S. Dist. LEXIS 22...  C:/Users/jacqu/Downloads/trials/78_cases_txt
# Ditullio v. Boehm, 2010 U.S. Dist. LEXIS 148772     C:/Users/jacqu/Downloads/trials/78_cases_txt

# %%
import pandas as pd
import numpy as np

# %%
labels = pd.read_csv(default_path+"trials/78_Cases.csv")

# %%
labels.head()
# Out:
#         STATE                                             AGENCY  \
# 0        Iowa  FBI-Southern District Iowa, Council Bluffs PD,...
# 1    New York                FBI-Eastern District New York, NYPD
# 2  California                         San Jose police department
# 3  California  Santa Barbara PD, FBI - National Center for Mi...
# 4    Michigan  Ingham County Sheirff's Office (MI), FBI - Wes...
#
#                    CRIME  CRIME_MINOR  CRIME_ADULT  \
# 0        sex trafficking            0            1
# 1  sex trafficking minor            1            0
# 2  sex trafficking minor            1            0
# 3  sex trafficking minor            1            0
# 4  sex trafficking minor            1            0
#
#                                           Unnamed: 5  \
# 0  united states court of appeals for the eighth ...
# 1  united states court of appeals for the second ...
# 2  court of appeal of california, sixth appellate...
# 3  court of appeal of california, second appellat...
# 4  united states court of appeals for the sixth c...
#
#                                                 NAME  Unnamed: 7  SEX T SCORE  \
# 0                                johnelle lewis bell         NaN   264.107143
# 1                                    alvaun thompson         NaN   250.766693
# 2  christopher lyon johnson, Antoine Williams of ...         NaN   240.432065
# 3                           brannon lawrence pitcher         NaN   201.644022
# 4                         christopher turryle bryant         NaN   189.000000
#
#    LABOR T SCORE
# 0         55.800
# 1         58.500
# 2        108.000
# 3        117.450
# 4         28.125
